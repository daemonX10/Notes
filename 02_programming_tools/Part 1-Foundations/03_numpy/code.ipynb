# %% [markdown]
# # Coding Examples and Practice
#
# This notebook contains coding examples and implementations related to the concepts in this folder.

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Example 1
#
# Add your code examples here.

# %%
arr = np.array([0, 20, 40, 50, 60, 7000, 80, 100])

# %%
print(np.percentile(arr,0))
print(np.percentile(arr,100))
print(np.percentile(arr,[0,25,50,75,100]))
# Out:
# 0.0
# 7000.0
# [   0.   35.   55.   85. 7000.]
